# %% [markdown]
# ## Getting tweets

# %% [markdown]
# Once you are set-up to access the twitter API (see the README.md in [this repository](https://github.com/datacamp/datacamp-metoo-analysis)), you can get the tweets necessary for this analysis.

# %%
# Store APIs creds in a dictionary
import yaml
with open('config.yml') as f:
    # use safe_load instead load
    d = yaml.safe_load(f)

# %%
#  Twitter API authentication
import tweepy
auth = tweepy.OAuthHandler(d['consumer_key'], d['consumer_secret'])
auth.set_access_token(d['access_token'], d['access_token_secret'])
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
# Read in tweet IDs
data = pd.read_csv('ids1.csv')

# Store in list tweets that still exist; print out IDs of those that have been deleted by tweeter
tweet_list = []
for i, row in data.iterrows():
    if i < 100:
        try:
            id_of_tweet = row['id']
            print(id_of_tweet)
            tweet_list.append(api.get_status(id_of_tweet))
        except:
            print(str(id_of_tweet) + ' not present any more')

# %%
# Tweets to DataFrame and save to .csv
tweet_dicts = [tweet._json for tweet in tweet_list]
df = pd.DataFrame(tweet_dicts)
df.to_csv('data/tweets1.csv', index=False)
df.head()
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Sat Nov 04 20:39:28 +0000 2017
# 1         None        None  Thu Nov 02 08:47:32 +0000 2017
# 2         None        None  Fri Nov 03 07:08:06 +0000 2017
# 3         None        None  Mon Oct 30 17:44:11 +0000 2017
# 4         None        None  Mon Oct 30 09:55:50 +0000 2017
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 1  {'hashtags': [{'text': 'MeToo', 'indices': [30...               NaN
# 2  {'hashtags': [{'text': 'AcosoSexual', 'indices...               NaN
# 3  {'hashtags': [{'text': 'Rechtsstaat', 'indices...               NaN
# 4  {'hashtags': [{'text': 'Metoo', 'indices': [0,...               NaN
#
#    favorite_count  favorited   geo                  id              id_str  \
# 0               0      False  None  926911797885657088  926911797885657088
# 1               0      False  None  926007858642214912  926007858642214912
# 2               0      False  None  926345224258977792  926345224258977792
# 3               0      False  None  925055745133023232  925055745133023232
# 4               0      False  None  924937883110334464  924937883110334464
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                        quoted_status  quoted_status_id  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4  {'created_at': 'Sun Oct 29 20:34:08 +0000 2017...      9.247361e+17
#
#   quoted_status_id_str  retweet_count retweeted  \
# 0                  NaN              0     False
# 1                  NaN              2     False
# 2                  NaN              0     False
# 3                  NaN              0     False
# 4   924736128816525312              0     False
#
#                                     retweeted_status  \
# 0                                                NaN
# 1  {'created_at': 'Thu Nov 02 08:46:28 +0000 2017...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://www.facebook.com/twitter" rel=...
# 3  <a href="https://mobile.twitter.com" rel="nofo...
# 4  <a href="http://twitter.com/#!/download/ipad" ...
#
#                                                 text truncated  \
# 0  @BreezyWinter @jatemple @yashar @netflix I'm r...      True
# 1  RT @fosslijensen: Psykolog om #MeToo: – Har pa...     False
# 2        #AcosoSexual #Metoo https://t.co/JVthDMkJCl     False
# 3  Wer so einen #Rechtsstaat hat, braucht keine F...     False
# 4  #Metoo If for several women this movement is a...      True
#
#                                                 user
# 0  {'id': 2586084062, 'id_str': '2586084062', 'na...
# 1  {'id': 41124241, 'id_str': '41124241', 'name':...
# 2  {'id': 709649007694520320, 'id_str': '70964900...
# 3  {'id': 440292565, 'id_str': '440292565', 'name...
# 4  {'id': 738986651653902336, 'id_str': '73898665...
#
# [5 rows x 30 columns]

# %%
# Do the same w/ 2nd list of ids (2nd wordcloud in article)
data2 = pd.read_csv('ids2.csv')
tweet_list2 = []
for i, row in data2.iterrows():
    if i < 100:
        try:
            id_of_tweet = row['id']
            print(id_of_tweet)
            tweet_list2.append(api.get_status(id_of_tweet))
        except:
            print(str(id_of_tweet) + ' not present any more')
# Out:
# 929207023136260096 not present any more
# 929206448021823488 not present any more
# 929205715297849344 not present any more

# %%
# 2nd list of tweets to DataFrames and .csv
tweet_dicts2 = [tweet._json for tweet in tweet_list2]
df2 = pd.DataFrame(tweet_dicts2)
df2.to_csv('data/tweets2.csv', index=False)
df2.head()
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Sat Nov 11 04:41:47 +0000 2017
# 1         None        None  Sat Nov 11 04:41:40 +0000 2017
# 2         None        None  Sat Nov 11 04:41:39 +0000 2017
# 3         None        None  Sat Nov 11 04:41:12 +0000 2017
# 4         None        None  Sat Nov 11 04:41:05 +0000 2017
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 2  {'hashtags': [{'text': 'MeToo', 'indices': [6,...               NaN
# 3  {'hashtags': [{'text': 'MeToo', 'indices': [57...               NaN
# 4  {'hashtags': [{'text': 'MeToo', 'indices': [67...               NaN
#
#    favorite_count  favorited   geo                  id              id_str  \
# 0               2      False  None  929207504843739136  929207504843739136
# 1               7      False  None  929207473273126913  929207473273126913
# 2               0      False  None  929207469728964608  929207469728964608
# 3               0      False  None  929207356050640896  929207356050640896
# 4              64      False  None  929207327940599808  929207327940599808
#
#                          ...                         quoted_status  \
# 0                        ...                                   NaN
# 1                        ...                                   NaN
# 2                        ...                                   NaN
# 3                        ...                                   NaN
# 4                        ...                                   NaN
#
#    quoted_status_id quoted_status_id_str  retweet_count retweeted  \
# 0               NaN                  NaN              0     False
# 1               NaN                  NaN              1     False
# 2               NaN                  NaN              0     False
# 3               NaN                  NaN             18     False
# 4               NaN                  NaN              0     False
#
#                                     retweeted_status  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {'created_at': 'Fri Nov 10 23:23:05 +0000 2017...
# 4                                                NaN
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com" rel="nofollow">Tw...
# 3  <a href="http://twitter.com/#!/download/ipad" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text truncated  \
# 0  Yeah just what I thought, America still sucks,...      True
# 1  Why should women MPs repeat/say what younger/n...      True
# 2  Okay, #MeToo is getting out of control. Asking...      True
# 3  RT @ETCanada: Watch: @SarahMcLachlan  opens up...     False
# 4  @rosemcgowan “Slandering all men?” Another one...     False
#
#                                                 user
# 0  {'id': 24087885, 'id_str': '24087885', 'name':...
# 1  {'id': 406579529, 'id_str': '406579529', 'name...
# 2  {'id': 16722659, 'id_str': '16722659', 'name':...
# 3  {'id': 36332025, 'id_str': '36332025', 'name':...
# 4  {'id': 19057726, 'id_str': '19057726', 'name':...
#
# [5 rows x 30 columns]
